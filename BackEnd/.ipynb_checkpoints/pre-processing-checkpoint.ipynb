# %%
# %matplotlib notebook
import mne
import matplotlib.pyplot as plt

# %%
fname = 'Data/S001R03.edf'
raw = mne.io.read_raw_edf(fname,preload=True)
# Out:
# Extracting EDF parameters from /home/jatin/Mind-ID/Data/S001R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...

# %%
channels = raw.ch_names

# %%
print(channels)
raw.info
# Out:
# ['Fc5.', 'Fc3.', 'Fc1.', 'Fcz.', 'Fc2.', 'Fc4.', 'Fc6.', 'C5..', 'C3..', 'C1..', 'Cz..', 'C2..', 'C4..', 'C6..', 'Cp5.', 'Cp3.', 'Cp1.', 'Cpz.', 'Cp2.', 'Cp4.', 'Cp6.', 'Fp1.', 'Fpz.', 'Fp2.', 'Af7.', 'Af3.', 'Afz.', 'Af4.', 'Af8.', 'F7..', 'F5..', 'F3..', 'F1..', 'Fz..', 'F2..', 'F4..', 'F6..', 'F8..', 'Ft7.', 'Ft8.', 'T7..', 'T8..', 'T9..', 'T10.', 'Tp7.', 'Tp8.', 'P7..', 'P5..', 'P3..', 'P1..', 'Pz..', 'P2..', 'P4..', 'P6..', 'P8..', 'Po7.', 'Po3.', 'Poz.', 'Po4.', 'Po8.', 'O1..', 'Oz..', 'O2..', 'Iz..']
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fc5., Fc3., Fc1., Fcz., Fc2., Fc4., Fc6., C5.., C3.., C1.., ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  highpass: 1.0 Hz
#  lowpass: 40.0 Hz
#  meas_date: 2009-08-12 16:15:00 UTC
#  nchan: 64
#  projs: []
#  sfreq: 160.0 Hz
# >

# %%
raw.plot_psd()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Effective window size : 12.800 (s)
# <ipython-input-100-a5fcf744740b>:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.plot_psd()
# <img src="data:image/png;base64,..." width="640">

# %%
raw.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
  print(i.ch_names)
    #print(raw.info)
    print(i.info['chs'][0]['loc'])
    for x in i.ch_names:
        str = x.replace(".", "")
        #print(str)
        i.rename_channels(mapping={x:str})
    print (i.ch_names)
    print(i.info['chs'][0]['loc'])

# %%
raw.filter(None, 50., h_trans_bandwidth='auto', filter_length='auto',
           phase='zero')
raw.filter(1, 40, n_jobs=2)  # 1Hz high pass is often helpful for fitting ICA


picks_meg = mne.pick_types(raw.info, meg=False, eeg=True, eog=False,
                           stim=False, exclude='bads')


montage =  mne.channels.make_standard_montage('biosemi64')
raw.set_montage(montage)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 43 samples (0.269 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 sec)
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  64 out of  64 | elapsed:    0.1s finished
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-d7c3d90c6a13> in <module>
#       9
#      10 montage =  mne.channels.make_standard_montage('biosemi64')
# ---> 11 raw.set_montage(montage)
#
# <decorator-gen-20> in set_montage(self, montage, raise_if_subset, match_case, verbose)
#
# ~/.local/lib/python3.6/site-packages/mne/io/meas_info.py in set_montage(self, montage, raise_if_subset, match_case, verbose)
#     187         from ..channels.montage import _set_montage
#     188         info = self if isinstance(self, Info) else self.info
# --> 189         _set_montage(info, montage, raise_if_subset, match_case)
#     190         return self
#     191
#
# ~/.local/lib/python3.6/site-packages/mne/channels/montage.py in _set_montage(info, montage, raise_if_subset, match_case)
#     742                              'the DigMontage. The required channels are: %s'
#     743                              % (len(not_in_montage), _pl(not_in_montage),
# --> 744                                 not_in_montage))
#     745
#     746         for name, use in zip(info_names, info_names_use):
#
# ValueError: DigMontage is a only a subset of info. There are 64 channel positions not present in the DigMontage. The required channels are: ['Fc5.', 'Fc3.', 'Fc1.', 'Fcz.', 'Fc2.', 'Fc4.', 'Fc6.', 'C5..', 'C3..', 'C1..', 'Cz..', 'C2..', 'C4..', 'C6..', 'Cp5.', 'Cp3.', 'Cp1.', 'Cpz.', 'Cp2.', 'Cp4.', 'Cp6.', 'Fp1.', 'Fpz.', 'Fp2.', 'Af7.', 'Af3.', 'Afz.', 'Af4.', 'Af8.', 'F7..', 'F5..', 'F3..', 'F1..', 'Fz..', 'F2..', 'F4..', 'F6..', 'F8..', 'Ft7.', 'Ft8.', 'T7..', 'T8..', 'T9..', 'T10.', 'Tp7.', 'Tp8.', 'P7..', 'P5..', 'P3..', 'P1..', 'Pz..', 'P2..', 'P4..', 'P6..', 'P8..', 'Po7.', 'Po3.', 'Poz.', 'Po4.', 'Po8.', 'O1..', 'Oz..', 'O2..', 'Iz..']

# %%
ica = mne.preprocessing.ICA(n_components=20,random_state=0)

# %%
ica.fit(raw.copy().filter(8,40))
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
#
# Fitting ICA to data using 64 channels (please be patient, this may take a while)
# Inferring max_pca_components from picks
# Selecting by number: 20 components
# Fitting ICA took 1.3s.
# <ICA  |  raw data decomposition, fit (fastica): 20000 samples, 20 components, channels used: "eeg">

# %%
ica.plot_components(outlines = 'skirt')
# Out:
# WARNING:root:Did not find any electrode locations (in the info object), will attempt to use digitization points instead. However, if digitization points do not correspond to the EEG electrodes, this will lead to bad results. Please verify that the sensor locations in the plot are accurate.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-104-cc6f364d5f9e> in <module>
# ----> 1 ica.plot_components(outlines = 'skirt')
#
# ~/.local/lib/python3.6/site-packages/mne/preprocessing/ica.py in plot_components(self, picks, ch_type, res, layout, vmin, vmax, cmap, sensors, colorbar, title, show, outlines, contours, image_interp, head_pos, inst, plot_std, topomap_args, image_args, psd_args, reject, sphere)
#    1621                                    topomap_args=topomap_args,
#    1622                                    image_args=image_args, psd_args=psd_args,
# -> 1623                                    reject=reject, sphere=sphere)
#    1624
#    1625     @copy_function_doc_to_method_doc(plot_ica_properties)
#
# ~/.local/lib/python3.6/site-packages/mne/viz/topomap.py in plot_ica_components(ica, picks, ch_type, res, layout, vmin, vmax, cmap, sensors, colorbar, title, show, outlines, contours, image_interp, head_pos, inst, plot_std, topomap_args, image_args, psd_args, reject, sphere)
#    1149                                       image_args=image_args,
#    1150                                       psd_args=psd_args, reject=reject,
# -> 1151                                       sphere=sphere)
#    1152             figs.append(fig)
#    1153         return figs
#
# ~/.local/lib/python3.6/site-packages/mne/viz/topomap.py in plot_ica_components(ica, picks, ch_type, res, layout, vmin, vmax, cmap, sensors, colorbar, title, show, outlines, contours, image_interp, head_pos, inst, plot_std, topomap_args, image_args, psd_args, reject, sphere)
#    1161
#    1162     data_picks, pos, merge_channels, names, _, sphere, clip_origin = \
# -> 1163         _prepare_topomap_plot(ica, ch_type, layout, sphere=sphere)
#    1164     outlines = _make_head_outlines(sphere, pos, outlines, clip_origin,
#    1165                                    head_pos)
#
# ~/.local/lib/python3.6/site-packages/mne/viz/topomap.py in _prepare_topomap_plot(***failed resolving arguments***)
#      89
#      90     # special case for merging grad channels
# ---> 91     layout = find_layout(info)
#      92     if (ch_type == 'grad' and layout is not None and
#      93             (layout.kind.startswith('Vectorview') or
#
# ~/.local/lib/python3.6/site-packages/mne/channels/layout.py in find_layout(info, ch_type, exclude)
#     417             raise RuntimeError('Cannot make EEG layout, no measurement info '
#     418                                'was passed to `find_layout`')
# --> 419         return make_eeg_layout(info, exclude=exclude)
#     420     elif has_4D_mag:
#     421         layout_name = 'magnesWH3600'
#
# ~/.local/lib/python3.6/site-packages/mne/channels/layout.py in make_eeg_layout(info, radius, width, height, exclude)
#     252     picks = pick_types(info, meg=False, eeg=True, ref_meg=False,
#     253                        exclude=exclude)
# --> 254     loc2d = _find_topomap_coords(info, picks)
#     255     names = [info['chs'][i]['ch_name'] for i in picks]
#     256
#
# ~/.local/lib/python3.6/site-packages/mne/channels/layout.py in _find_topomap_coords(info, picks, layout, ignore_overlap, to_sphere, sphere)
#     615         pos = _auto_topomap_coords(
#     616             info, picks, ignore_overlap=ignore_overlap, to_sphere=to_sphere,
# --> 617             sphere=sphere)
#     618
#     619     return pos
#
# ~/.local/lib/python3.6/site-packages/mne/channels/layout.py in _auto_topomap_coords(info, picks, ignore_overlap, to_sphere, sphere)
#     677         # Get EEG digitization points
#     678         if info['dig'] is None or len(info['dig']) == 0:
# --> 679             raise RuntimeError('No digitization points found.')
#     680
#     681         locs3d = np.array([point['r'] for point in info['dig']
#
# RuntimeError: No digitization points found.
